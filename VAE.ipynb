# %% [markdown]
# **VAE for Ultrasount Breast cancer dataset (Normal, bening, and malignant)**

# %%
import os
import time
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import (Input, Dense, Lambda, Flatten, Reshape,
                                   Conv2D, Conv2DTranspose, Layer)
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
from tensorflow.image import ssim, psnr
from tensorflow.keras.applications.inception_v3 import InceptionV3, preprocess_input
from scipy.linalg import sqrtm
from tensorflow.keras.callbacks import History
from tensorflow.keras.utils import plot_model

# Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Define image dimensions
img_shape = (128, 128, 3)
latent_dim = 100
max_images_per_class = 1000

# Performance tracking class
class PerformanceTracker:
    def __init__(self):
        self.metrics = {
            'training_time': [],
            'inference_time': [],
            'gpu_memory': [],
            'mse': [],
            'psnr': [],
            'ssim': [],
            'fid': []
        }

    def start_timer(self):
        self.start_time = time.time()

    def record_training_time(self):
        elapsed = time.time() - self.start_time
        self.metrics['training_time'].append(elapsed)
        return elapsed

    def record_inference_time(self, batch_size):
        elapsed = (time.time() - self.start_time) / batch_size
        self.metrics['inference_time'].append(elapsed)
        return elapsed

    def get_gpu_memory(self):
        try:
            from pynvml import nvmlInit, nvmlDeviceGetHandleByIndex, nvmlDeviceGetMemoryInfo
            nvmlInit()
            handle = nvmlDeviceGetHandleByIndex(0)
            info = nvmlDeviceGetMemoryInfo(handle)
            return info.used // 1024 // 1024  # Convert to MB
        except:
            return None

    def record_metrics(self, mse, psnr, ssim, fid):
        self.metrics['mse'].append(mse)
        self.metrics['psnr'].append(psnr)
        self.metrics['ssim'].append(ssim)
        self.metrics['fid'].append(fid)

    def print_summary(self, class_name):
        print(f"\n=== Performance Summary for {class_name.upper()} ===")
        print(f"Training time: {np.mean(self.metrics['training_time']):.2f} ± {np.std(self.metrics['training_time']):.2f} sec")
        print(f"Inference time: {np.mean(self.metrics['inference_time']) * 1000:.2f} ± {np.std(self.metrics['inference_time']) * 1000:.2f} ms per image")
        if any(self.metrics['gpu_memory']):
            print(f"GPU memory usage: {np.mean(self.metrics['gpu_memory']):.0f} ± {np.std(self.metrics['gpu_memory']):.0f} MB")
        print(f"Reconstruction quality:")
        print(f"- MSE: {np.mean(self.metrics['mse']):.4f}")
        print(f"- PSNR: {np.mean(self.metrics['psnr']):.2f} dB")
        print(f"- SSIM: {np.mean(self.metrics['ssim']):.4f}")
        print(f"- FID: {np.mean(self.metrics['fid']):.2f}")

# Function to Load Images
def load_images(directory, img_size):
    images = []
    for filename in os.listdir(directory):
        img_path = os.path.join(directory, filename)
        try:
            img = load_img(img_path, target_size=img_size)
            img = img_to_array(img) / 255.0
            images.append(img)
        except Exception as e:
            print(f"Error loading {img_path}: {e}")
    return np.array(images)

# Load datasets for all three classes
base_dir = '/content/drive/MyDrive/Breast'
class_dirs = {
    'normal': os.path.join(base_dir, 'normal'),
    'benign': os.path.join(base_dir, 'benign'),
    'malignant': os.path.join(base_dir, 'malignant')
}

# Check if directories exist and load images
x_train = {}
for class_name, data_dir in class_dirs.items():
    if not os.path.exists(data_dir):
        raise ValueError(f"Directory {data_dir} does not exist! Check the path.")
    x_train[class_name] = load_images(data_dir, (128, 128))
    print(f"Loaded {len(x_train[class_name])} images for class {class_name}")

# Simplified Encoder (without intermediate features return)
def build_encoder():
    inputs = Input(shape=img_shape)

    # Conv blocks
    x = Conv2D(32, kernel_size=3, strides=2, padding='same', activation='relu')(inputs)
    x = Conv2D(64, kernel_size=3, strides=2, padding='same', activation='relu')(x)

    # Flatten and get latent distribution parameters
    x = Flatten()(x)
    x = Dense(256, activation='relu')(x)

    z_mean = Dense(latent_dim, name='z_mean')(x)
    z_log_var = Dense(latent_dim, name='z_log_var')(x)

    # Sampling function
    def sampling(args):
        z_mean, z_log_var = args
        batch = K.shape(z_mean)[0]
        dim = K.int_shape(z_mean)[1]
        epsilon = K.random_normal(shape=(batch, dim))
        return z_mean + K.exp(0.5 * z_log_var) * epsilon

    z = Lambda(sampling, output_shape=(latent_dim,), name='z')([z_mean, z_log_var])

    return Model(inputs, [z_mean, z_log_var, z], name='encoder')

# Simplified Decoder (without cross-attention)
def build_decoder():
    latent_inputs = Input(shape=(latent_dim,))

    # Process latent vector
    x = Dense(16 * 16 * 64, activation='relu')(latent_inputs)
    x = Reshape((16, 16, 64))(x)

    # Upsampling
    x = Conv2DTranspose(64, kernel_size=3, strides=2, padding='same', activation='relu')(x)
    x = Conv2DTranspose(32, kernel_size=3, strides=2, padding='same', activation='relu')(x)
    outputs = Conv2DTranspose(3, kernel_size=3, strides=2, padding='same', activation='sigmoid')(x)

    return Model(latent_inputs, outputs, name='decoder')

# Custom Loss Layer (same as original)
class VAELossLayer(Layer):
    def __init__(self, **kwargs):
        super(VAELossLayer, self).__init__(**kwargs)

    def vae_loss(self, inputs, outputs, z_mean, z_log_var):
        reconstruction_loss = tf.keras.losses.binary_crossentropy(
            K.flatten(inputs), K.flatten(outputs))
        reconstruction_loss = tf.reduce_mean(reconstruction_loss) * np.prod(img_shape)

        kl_loss = -0.5 * tf.reduce_sum(
            1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var), axis=-1)
        return tf.reduce_mean(reconstruction_loss + kl_loss)

    def call(self, inputs):
        inputs, outputs, z_mean, z_log_var = inputs
        loss = self.vae_loss(inputs, outputs, z_mean, z_log_var)
        self.add_loss(loss)
        return outputs

def build_vae(encoder, decoder):
    inputs = Input(shape=img_shape)
    z_mean, z_log_var, z = encoder(inputs)
    outputs = decoder(z)
    outputs = VAELossLayer()([inputs, outputs, z_mean, z_log_var])
    return Model(inputs, outputs, name='vae')

# Function to calculate evaluation metrics (same as original)
def evaluate_model(encoder, decoder, vae, x_test):
    reconstructed_images = vae.predict(x_test)

    mse_scores = np.mean(np.square(x_test - reconstructed_images), axis=(1, 2, 3))
    psnr_scores = [psnr(x_test[i], reconstructed_images[i], max_val=1.0).numpy() for i in range(len(x_test))]
    ssim_scores = [ssim(x_test[i], reconstructed_images[i], max_val=1.0).numpy() for i in range(len(x_test))]

    avg_mse = np.mean(mse_scores)
    avg_psnr = np.mean(psnr_scores)
    avg_ssim = np.mean(ssim_scores)

    return avg_mse, avg_psnr, avg_ssim

# Load InceptionV3 model for FID calculation
fid_model = InceptionV3(include_top=False, pooling='avg', input_shape=(128, 128, 3))

# Function to compute FID Score (same as original)
def calculate_fid(real_images, generated_images):
    real_images = preprocess_input(real_images)
    generated_images = preprocess_input(generated_images)

    act_real = fid_model.predict(real_images)
    act_generated = fid_model.predict(generated_images)

    mu_real, sigma_real = np.mean(act_real, axis=0), np.cov(act_real, rowvar=False)
    mu_generated, sigma_generated = np.mean(act_generated, axis=0), np.cov(act_generated, rowvar=False)

    mean_diff = np.sum((mu_real - mu_generated) ** 2)
    covmean, _ = sqrtm(sigma_real.dot(sigma_generated), disp=False)

    if np.iscomplexobj(covmean):
        covmean = covmean.real

    fid_score = mean_diff + np.trace(sigma_real + sigma_generated - 2 * covmean)
    return fid_score

# Train separate VAEs for each class
for class_name, images in x_train.items():
    tracker = PerformanceTracker()
    print(f"\n=== Training VAE for class: {class_name.upper()} ===")
    print(f"Training samples: {len(images)}")

    # Build models
    encoder = build_encoder()
    decoder = build_decoder()
    vae = build_vae(encoder, decoder)
    vae.compile(optimizer='adam')

    # Start training timer
    tracker.start_timer()

    # Train the model and store history
    history = vae.fit(images, epochs=500, batch_size=64, verbose=1)

    # Plot training history
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.title(f'Training Loss Curve for {class_name.upper()}')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    # Save the loss curve plot
    loss_curve_path = os.path.join(base_dir, f'loss_curve_{class_name}.png')
    plt.savefig(loss_curve_path)
    plt.close()
    print(f"Saved loss curve plot at: {loss_curve_path}")

    # Record training time
    training_time = tracker.record_training_time()
    print(f"Training completed in {training_time:.2f} seconds")

    # Record GPU memory
    gpu_mem = tracker.get_gpu_memory()
    if gpu_mem:
        tracker.metrics['gpu_memory'].append(gpu_mem)
        print(f"GPU memory used: {gpu_mem} MB")

    # Create a directory to save models for this class
    models_dir = os.path.join(base_dir, f'saved_models_VAE_Breast_{class_name}')
    os.makedirs(models_dir, exist_ok=True)

    # Save models
    encoder.save(os.path.join(models_dir, 'encoder.h5'))
    decoder.save(os.path.join(models_dir, 'decoder.h5'))
    vae.save(os.path.join(models_dir, 'vae.h5'))

    # Save model architecture diagrams
    try:
        encoder_path = os.path.join(models_dir, 'encoder_architecture.png')
        decoder_path = os.path.join(models_dir, 'decoder_architecture.png')
        vae_path = os.path.join(models_dir, 'vae_architecture.png')

        plot_model(encoder, to_file=encoder_path, show_shapes=True, show_layer_names=True)
        plot_model(decoder, to_file=decoder_path, show_shapes=True, show_layer_names=True)
        plot_model(vae, to_file=vae_path, show_shapes=True, show_layer_names=True)

        print(f"Saved model architecture diagrams in {models_dir}")
    except Exception as e:
        print(f"Error saving model architecture diagrams: {e}")

    print(f"Saved models for {class_name} in {models_dir}")

    # Create output directory for generated images
    output_dir = os.path.join(base_dir, f'generated_VAE_Breast_{class_name}')
    os.makedirs(output_dir, exist_ok=True)

    # Calculate how many images to generate
    num_real_images = len(images)
    num_to_generate = max(0, max_images_per_class - num_real_images)

    if num_to_generate > 0:
        print(f"Generating {num_to_generate} images for class {class_name}")
        latent_vectors = np.random.normal(size=(num_to_generate, latent_dim))
        generated_images = decoder.predict(latent_vectors)

        # Save generated images
        for i in range(num_to_generate):
            img_path = os.path.join(output_dir, f'generated_{i}.png')
            plt.imsave(img_path, generated_images[i])

    # Evaluate the model
    print(f"\nEvaluating model for class: {class_name}")
    x_test_sample = images[:min(10, len(images))]

    # Measure inference speed
    tracker.start_timer()
    _ = vae.predict(x_test_sample)
    inference_time = tracker.record_inference_time(len(x_test_sample))
    print(f"Inference speed: {inference_time*1000:.2f} ms per image")

    # Calculate quality metrics
    mse, psnr_score, ssim_score = evaluate_model(encoder, decoder, vae, x_test_sample)
    print(f"Reconstruction quality:")
    print(f"- MSE: {mse:.4f}")
    print(f"- PSNR: {psnr_score:.2f} dB")
    print(f"- SSIM: {ssim_score:.4f}")

    # Calculate FID score
    if len(x_test_sample) > 0:
        latent_vectors = np.random.normal(size=(len(x_test_sample), latent_dim))
        generated_for_fid = decoder.predict(latent_vectors)
        fid_score = calculate_fid(x_test_sample, generated_for_fid)
        print(f"- FID: {fid_score:.2f}")
    else:
        fid_score = float('nan')

    # Record all metrics
    tracker.record_metrics(mse, psnr_score, ssim_score, fid_score)

    # Print summary
    tracker.print_summary(class_name)

# Create and save a comprehensive system diagram
try:
    # Create a temporary model that shows the full flow
    inputs = Input(shape=img_shape)
    z_mean, z_log_var, z = encoder(inputs)
    outputs = decoder(z)
    full_system = Model(inputs, outputs, name='full_vae_system')

    system_diagram_path = os.path.join(base_dir, 'full_system_architecture.png')
    plot_model(full_system, to_file=system_diagram_path, show_shapes=True, show_layer_names=True)
    print(f"\nSaved full system architecture diagram at: {system_diagram_path}")
except Exception as e:
    print(f"\nError creating full system diagram: {e}")

# Display all loss curves at the end
plt.figure(figsize=(15, 10))
for i, class_name in enumerate(x_train.keys()):
    loss_curve_path = os.path.join(base_dir, f'loss_curve_{class_name}.png')
    if os.path.exists(loss_curve_path):
        img = plt.imread(loss_curve_path)
        plt.subplot(2, 2, i+1)
        plt.imshow(img)
        plt.axis('off')
        plt.title(f'{class_name.upper()} Loss Curve')
plt.tight_layout()
plt.show()

# Model summaries
print("\n=== Model Architectures ===")
encoder.summary()
decoder.summary()
vae.summary()
# Out:
# Loaded 133 images for class normal
# Loaded 437 images for class benign
# Loaded 210 images for class malignant
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step
#
# === Training VAE for class: NORMAL ===
# Training samples: 133
# Epoch 1/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 34082.0039
# Epoch 2/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 33967.5859
# Epoch 3/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 33809.8164
# Epoch 4/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 33506.0547
# Epoch 5/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 32483.8984
# Epoch 6/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 31290.4824
# Epoch 7/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 30372.9766
# Epoch 8/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 29648.3887
# Epoch 9/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 29123.8105
# Epoch 10/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 28541.7930
# Epoch 11/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 28252.1367
# Epoch 12/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 28340.0234
# Epoch 13/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 28266.0352
# Epoch 14/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 28308.2422
# Epoch 15/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 28058.7930
# Epoch 16/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 28051.7637
# Epoch 17/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 28005.6582
# Epoch 18/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 27997.7500
# Epoch 19/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 28025.3125
# Epoch 20/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 27884.1797
# Epoch 21/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 27852.6445
# Epoch 22/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 27799.8750
# Epoch 23/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 27821.8086
# Epoch 24/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 27783.8613
# Epoch 25/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 27715.0605
# Epoch 26/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 27699.6270
# Epoch 27/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 27710.1660
# Epoch 28/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 27641.8477
# Epoch 29/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 27650.4688
# Epoch 30/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 27595.5781
# Epoch 31/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 27504.0469
# Epoch 32/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 27449.2363
# Epoch 33/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 27439.5723
# Epoch 34/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 27378.0742
# Epoch 35/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 27338.7051
# Epoch 36/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 27358.4141
# Epoch 37/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 27330.1602
# Epoch 38/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 27310.3848
# Epoch 39/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 27251.6641
# Epoch 40/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 27252.7559
# Epoch 41/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 27213.6582
# Epoch 42/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 27196.8945
# Epoch 43/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 27172.9590
# Epoch 44/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 27153.7832
# Epoch 45/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 27157.6484
# Epoch 46/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 27124.5430
# Epoch 47/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 27143.3184
# Epoch 48/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 27128.8477
# Epoch 49/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 27105.8711
# Epoch 50/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 27087.3379
# Epoch 51/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 27079.0078
# Epoch 52/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 27082.5391
# Epoch 53/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 27089.3613
# Epoch 54/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 27082.3457
# Epoch 55/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 27064.2617
# Epoch 56/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 27054.3887
# Epoch 57/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 27043.0293
# Epoch 58/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 27031.3594
# Epoch 59/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 27017.5508
# Epoch 60/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 27049.4160
# Epoch 61/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 27080.4277
# Epoch 62/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 27028.8496
# Epoch 63/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 27011.6172
# Epoch 64/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 27031.3574
# Epoch 65/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 26990.6348
# Epoch 66/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 26984.6602
# Epoch 67/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 27009.3008
# Epoch 68/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 26997.7285
# Epoch 69/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 26975.8887
# Epoch 70/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 26971.5820
# Epoch 71/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 26990.3379
# Epoch 72/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 26954.9316
# Epoch 73/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 26987.1230
# Epoch 74/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 26975.9668
# Epoch 75/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 26982.1504
# Epoch 76/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 27006.6484
# Epoch 77/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 27082.7168
# Epoch 78/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 26979.4355
# Epoch 79/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 26977.7891
# Epoch 80/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 26921.5547
# Epoch 81/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 26913.4141
# Epoch 82/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 26888.3574
# Epoch 83/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 26863.8789
# Epoch 84/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 26879.3613
# Epoch 85/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 26867.2656
# Epoch 86/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 26856.9141
# Epoch 87/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 26851.7148
# Epoch 88/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 26838.7695
# Epoch 89/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 26828.8770
# Epoch 90/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 26824.9727
# Epoch 91/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 26842.8145
# Epoch 92/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 26861.5215
# Epoch 93/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 26869.8516
# Epoch 94/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 26837.5781
# Epoch 95/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 26828.5391
# Epoch 96/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 26813.8301
# Epoch 97/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 26796.9141
# Epoch 98/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 26798.9062
# Epoch 99/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 26785.1973
# Epoch 100/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 26783.0312
# Epoch 101/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 26780.0938
# Epoch 102/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 26783.3145
# Epoch 103/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 26767.5566
# Epoch 104/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 
     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 55,677,923 (212.39 MB)
#  Trainable params: 18,559,307 (70.80 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 37,118,616 (141.60 MB)

# %% [markdown]
# **`VAE for Brats 2020 dataset (Tumor and No Tumor)`**

# %%
import os
import time
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import (Input, Dense, Lambda, Flatten, Reshape,
                                   Conv2D, Conv2DTranspose, Layer)
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import matplotlib.pyplot as plt
from tensorflow.image import ssim, psnr
from tensorflow.keras.applications.inception_v3 import InceptionV3, preprocess_input
from scipy.linalg import sqrtm
from tensorflow.keras.callbacks import History
from tensorflow.keras.utils import plot_model

# Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Define image dimensions
img_shape = (128, 128, 3)
latent_dim = 100
max_images_per_class = 1000

# Performance tracking class
class PerformanceTracker:
    def __init__(self):
        self.metrics = {
            'training_time': [],
            'inference_time': [],
            'gpu_memory': [],
            'mse': [],
            'psnr': [],
            'ssim': [],
            'fid': []
        }

    def start_timer(self):
        self.start_time = time.time()

    def record_training_time(self):
        elapsed = time.time() - self.start_time
        self.metrics['training_time'].append(elapsed)
        return elapsed

    def record_inference_time(self, batch_size):
        elapsed = (time.time() - self.start_time) / batch_size
        self.metrics['inference_time'].append(elapsed)
        return elapsed

    def get_gpu_memory(self):
        try:
            from pynvml import nvmlInit, nvmlDeviceGetHandleByIndex, nvmlDeviceGetMemoryInfo
            nvmlInit()
            handle = nvmlDeviceGetHandleByIndex(0)
            info = nvmlDeviceGetMemoryInfo(handle)
            return info.used // 1024 // 1024  # Convert to MB
        except:
            return None

    def record_metrics(self, mse, psnr, ssim, fid):
        self.metrics['mse'].append(mse)
        self.metrics['psnr'].append(psnr)
        self.metrics['ssim'].append(ssim)
        self.metrics['fid'].append(fid)

    def print_summary(self, class_name):
        print(f"\n=== Performance Summary for {class_name.upper()} ===")
        print(f"Training time: {np.mean(self.metrics['training_time']):.2f} ± {np.std(self.metrics['training_time']):.2f} sec")
        print(f"Inference time: {np.mean(self.metrics['inference_time']) * 1000:.2f} ± {np.std(self.metrics['inference_time']) * 1000:.2f} ms per image")
        if any(self.metrics['gpu_memory']):
            print(f"GPU memory usage: {np.mean(self.metrics['gpu_memory']):.0f} ± {np.std(self.metrics['gpu_memory']):.0f} MB")
        print(f"Reconstruction quality:")
        print(f"- MSE: {np.mean(self.metrics['mse']):.4f}")
        print(f"- PSNR: {np.mean(self.metrics['psnr']):.2f} dB")
        print(f"- SSIM: {np.mean(self.metrics['ssim']):.4f}")
        print(f"- FID: {np.mean(self.metrics['fid']):.2f}")

# Function to Load Images
def load_images(directory, img_size):
    images = []
    for filename in os.listdir(directory):
        img_path = os.path.join(directory, filename)
        try:
            img = load_img(img_path, target_size=img_size)
            img = img_to_array(img) / 255.0
            images.append(img)
        except Exception as e:
            print(f"Error loading {img_path}: {e}")
    return np.array(images)

# Load datasets for all three classes
base_dir = '/content/drive/MyDrive/BRATS20/Pre_BraTS20_flair'
class_dirs = {
    'Tumor': os.path.join(base_dir, 'Tumor'),
    'NoTumor': os.path.join(base_dir, 'NoTumor')
}

# Check if directories exist and load images
x_train = {}
for class_name, data_dir in class_dirs.items():
    if not os.path.exists(data_dir):
        raise ValueError(f"Directory {data_dir} does not exist! Check the path.")
    x_train[class_name] = load_images(data_dir, (128, 128))
    print(f"Loaded {len(x_train[class_name])} images for class {class_name}")

# Simplified Encoder (without intermediate features return)
def build_encoder():
    inputs = Input(shape=img_shape)

    # Conv blocks
    x = Conv2D(32, kernel_size=3, strides=2, padding='same', activation='relu')(inputs)
    x = Conv2D(64, kernel_size=3, strides=2, padding='same', activation='relu')(x)

    # Flatten and get latent distribution parameters
    x = Flatten()(x)
    x = Dense(256, activation='relu')(x)

    z_mean = Dense(latent_dim, name='z_mean')(x)
    z_log_var = Dense(latent_dim, name='z_log_var')(x)

    # Sampling function
    def sampling(args):
        z_mean, z_log_var = args
        batch = K.shape(z_mean)[0]
        dim = K.int_shape(z_mean)[1]
        epsilon = K.random_normal(shape=(batch, dim))
        return z_mean + K.exp(0.5 * z_log_var) * epsilon

    z = Lambda(sampling, output_shape=(latent_dim,), name='z')([z_mean, z_log_var])

    return Model(inputs, [z_mean, z_log_var, z], name='encoder')

# Simplified Decoder (without cross-attention)
def build_decoder():
    latent_inputs = Input(shape=(latent_dim,))

    # Process latent vector
    x = Dense(16 * 16 * 64, activation='relu')(latent_inputs)
    x = Reshape((16, 16, 64))(x)

    # Upsampling
    x = Conv2DTranspose(64, kernel_size=3, strides=2, padding='same', activation='relu')(x)
    x = Conv2DTranspose(32, kernel_size=3, strides=2, padding='same', activation='relu')(x)
    outputs = Conv2DTranspose(3, kernel_size=3, strides=2, padding='same', activation='sigmoid')(x)

    return Model(latent_inputs, outputs, name='decoder')

# Custom Loss Layer (same as original)
class VAELossLayer(Layer):
    def __init__(self, **kwargs):
        super(VAELossLayer, self).__init__(**kwargs)

    def vae_loss(self, inputs, outputs, z_mean, z_log_var):
        reconstruction_loss = tf.keras.losses.binary_crossentropy(
            K.flatten(inputs), K.flatten(outputs))
        reconstruction_loss = tf.reduce_mean(reconstruction_loss) * np.prod(img_shape)

        kl_loss = -0.5 * tf.reduce_sum(
            1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var), axis=-1)
        return tf.reduce_mean(reconstruction_loss + kl_loss)

    def call(self, inputs):
        inputs, outputs, z_mean, z_log_var = inputs
        loss = self.vae_loss(inputs, outputs, z_mean, z_log_var)
        self.add_loss(loss)
        return outputs

def build_vae(encoder, decoder):
    inputs = Input(shape=img_shape)
    z_mean, z_log_var, z = encoder(inputs)
    outputs = decoder(z)
    outputs = VAELossLayer()([inputs, outputs, z_mean, z_log_var])
    return Model(inputs, outputs, name='vae')

# Function to calculate evaluation metrics (same as original)
def evaluate_model(encoder, decoder, vae, x_test):
    reconstructed_images = vae.predict(x_test)

    mse_scores = np.mean(np.square(x_test - reconstructed_images), axis=(1, 2, 3))
    psnr_scores = [psnr(x_test[i], reconstructed_images[i], max_val=1.0).numpy() for i in range(len(x_test))]
    ssim_scores = [ssim(x_test[i], reconstructed_images[i], max_val=1.0).numpy() for i in range(len(x_test))]

    avg_mse = np.mean(mse_scores)
    avg_psnr = np.mean(psnr_scores)
    avg_ssim = np.mean(ssim_scores)

    return avg_mse, avg_psnr, avg_ssim

# Load InceptionV3 model for FID calculation
fid_model = InceptionV3(include_top=False, pooling='avg', input_shape=(128, 128, 3))

# Function to compute FID Score (same as original)
def calculate_fid(real_images, generated_images):
    real_images = preprocess_input(real_images)
    generated_images = preprocess_input(generated_images)

    act_real = fid_model.predict(real_images)
    act_generated = fid_model.predict(generated_images)

    mu_real, sigma_real = np.mean(act_real, axis=0), np.cov(act_real, rowvar=False)
    mu_generated, sigma_generated = np.mean(act_generated, axis=0), np.cov(act_generated, rowvar=False)

    mean_diff = np.sum((mu_real - mu_generated) ** 2)
    covmean, _ = sqrtm(sigma_real.dot(sigma_generated), disp=False)

    if np.iscomplexobj(covmean):
        covmean = covmean.real

    fid_score = mean_diff + np.trace(sigma_real + sigma_generated - 2 * covmean)
    return fid_score

# Train separate VAEs for each class
for class_name, images in x_train.items():
    tracker = PerformanceTracker()
    print(f"\n=== Training VAE for class: {class_name.upper()} ===")
    print(f"Training samples: {len(images)}")

    # Build models
    encoder = build_encoder()
    decoder = build_decoder()
    vae = build_vae(encoder, decoder)
    vae.compile(optimizer='adam')

    # Start training timer
    tracker.start_timer()

    # Train the model and store history
    history = vae.fit(images, epochs=500, batch_size=64, verbose=1)

    # Plot training history
    plt.figure(figsize=(10, 6))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.title(f'Training Loss Curve for {class_name.upper()}')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    # Save the loss curve plot
    loss_curve_path = os.path.join(base_dir, f'loss_curve_{class_name}.png')
    plt.savefig(loss_curve_path)
    plt.close()
    print(f"Saved loss curve plot at: {loss_curve_path}")

    # Record training time
    training_time = tracker.record_training_time()
    print(f"Training completed in {training_time:.2f} seconds")

    # Record GPU memory
    gpu_mem = tracker.get_gpu_memory()
    if gpu_mem:
        tracker.metrics['gpu_memory'].append(gpu_mem)
        print(f"GPU memory used: {gpu_mem} MB")

    # Create a directory to save models for this class
    models_dir = os.path.join(base_dir, f'saved_models_VAE_Brain_{class_name}')
    os.makedirs(models_dir, exist_ok=True)

    # Save models
    encoder.save(os.path.join(models_dir, 'encoder.h5'))
    decoder.save(os.path.join(models_dir, 'decoder.h5'))
    vae.save(os.path.join(models_dir, 'vae.h5'))

    # Save model architecture diagrams
    try:
        encoder_path = os.path.join(models_dir, 'encoder_architecture.png')
        decoder_path = os.path.join(models_dir, 'decoder_architecture.png')
        vae_path = os.path.join(models_dir, 'vae_architecture.png')

        plot_model(encoder, to_file=encoder_path, show_shapes=True, show_layer_names=True)
        plot_model(decoder, to_file=decoder_path, show_shapes=True, show_layer_names=True)
        plot_model(vae, to_file=vae_path, show_shapes=True, show_layer_names=True)

        print(f"Saved model architecture diagrams in {models_dir}")
    except Exception as e:
        print(f"Error saving model architecture diagrams: {e}")

    print(f"Saved models for {class_name} in {models_dir}")

    # Create output directory for generated images
    output_dir = os.path.join(base_dir, f'generated_VAE_Brain_{class_name}')
    os.makedirs(output_dir, exist_ok=True)

    # Calculate how many images to generate
    num_real_images = len(images)
    num_to_generate = max(0, max_images_per_class - num_real_images)

    if num_to_generate > 0:
        print(f"Generating {num_to_generate} images for class {class_name}")
        latent_vectors = np.random.normal(size=(num_to_generate, latent_dim))
        generated_images = decoder.predict(latent_vectors)

        # Save generated images
        for i in range(num_to_generate):
            img_path = os.path.join(output_dir, f'generated_{i}.png')
            plt.imsave(img_path, generated_images[i])

    # Evaluate the model
    print(f"\nEvaluating model for class: {class_name}")
    x_test_sample = images[:min(10, len(images))]

    # Measure inference speed
    tracker.start_timer()
    _ = vae.predict(x_test_sample)
    inference_time = tracker.record_inference_time(len(x_test_sample))
    print(f"Inference speed: {inference_time*1000:.2f} ms per image")

    # Calculate quality metrics
    mse, psnr_score, ssim_score = evaluate_model(encoder, decoder, vae, x_test_sample)
    print(f"Reconstruction quality:")
    print(f"- MSE: {mse:.4f}")
    print(f"- PSNR: {psnr_score:.2f} dB")
    print(f"- SSIM: {ssim_score:.4f}")

    # Calculate FID score
    if len(x_test_sample) > 0:
        latent_vectors = np.random.normal(size=(len(x_test_sample), latent_dim))
        generated_for_fid = decoder.predict(latent_vectors)
        fid_score = calculate_fid(x_test_sample, generated_for_fid)
        print(f"- FID: {fid_score:.2f}")
    else:
        fid_score = float('nan')

    # Record all metrics
    tracker.record_metrics(mse, psnr_score, ssim_score, fid_score)

    # Print summary
    tracker.print_summary(class_name)

# Create and save a comprehensive system diagram
try:
    # Create a temporary model that shows the full flow
    inputs = Input(shape=img_shape)
    z_mean, z_log_var, z = encoder(inputs)
    outputs = decoder(z)
    full_system = Model(inputs, outputs, name='full_vae_system')

    system_diagram_path = os.path.join(base_dir, 'full_system_architecture.png')
    plot_model(full_system, to_file=system_diagram_path, show_shapes=True, show_layer_names=True)
    print(f"\nSaved full system architecture diagram at: {system_diagram_path}")
except Exception as e:
    print(f"\nError creating full system diagram: {e}")

# Display all loss curves at the end
plt.figure(figsize=(15, 10))
for i, class_name in enumerate(x_train.keys()):
    loss_curve_path = os.path.join(base_dir, f'loss_curve_{class_name}.png')
    if os.path.exists(loss_curve_path):
        img = plt.imread(loss_curve_path)
        plt.subplot(2, 2, i+1)
        plt.imshow(img)
        plt.axis('off')
        plt.title(f'{class_name.upper()} Loss Curve')
plt.tight_layout()
plt.show()

# Model summaries
print("\n=== Model Architectures ===")
encoder.summary()
decoder.summary()
vae.summary()
# Out:
# Loaded 830 images for class Tumor
# Loaded 277 images for class NoTumor
#
# === Training VAE for class: TUMOR ===
# Training samples: 830
# Epoch 1/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 336ms/step - loss: 33306.3047
# Epoch 2/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 18987.1387
# Epoch 3/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 13217.0078
# Epoch 4/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 12353.2500
# Epoch 5/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 11968.2773
# Epoch 6/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 11741.4443
# Epoch 7/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 11623.4414
# Epoch 8/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 11544.0410
# Epoch 9/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 11484.6172
# Epoch 10/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 11414.6250
# Epoch 11/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 11319.9111
# Epoch 12/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 11203.7402
# Epoch 13/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 11103.1201
# Epoch 14/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 11048.7559
# Epoch 15/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 11000.5498
# Epoch 16/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 10972.4326
# Epoch 17/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 10928.0156
# Epoch 18/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 10898.6680
# Epoch 19/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 10871.2285
# Epoch 20/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 10876.5498
# Epoch 21/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 10848.0312
# Epoch 22/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 10812.1426
# Epoch 23/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 10792.1396
# Epoch 24/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 10772.5205
# Epoch 25/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 10754.9844
# Epoch 26/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 10761.8447
# Epoch 27/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 10749.4854
# Epoch 28/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 10720.1777
# Epoch 29/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 10724.7168
# Epoch 30/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 10751.1973
# Epoch 31/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 10811.6074
# Epoch 32/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 10780.6523
# Epoch 33/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 10687.5986
# Epoch 34/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 10688.5410
# Epoch 35/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 10666.4014
# Epoch 36/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 10654.1807
# Epoch 37/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 10651.1582
# Epoch 38/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 10642.0137
# Epoch 39/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 10638.3486
# Epoch 40/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 
500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 10146.3906
# Epoch 449/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 10144.1396
# Epoch 450/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 10147.6045
# Epoch 451/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 10128.5029
# Epoch 452/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 10110.2725
# Epoch 453/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 10129.7588
# Epoch 454/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 10110.0576
# Epoch 455/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 10117.5625
# Epoch 456/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 10110.5469
# Epoch 457/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 10108.9424
# Epoch 458/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 10114.9121
# Epoch 459/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 10112.2188
# Epoch 460/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 10117.8291
# Epoch 461/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 10116.6045
# Epoch 462/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 10107.5361
# Epoch 463/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 10103.2773
# Epoch 464/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 10105.0205
# Epoch 465/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 10096.4570
# Epoch 466/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 10100.4150
# Epoch 467/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 10104.2207
# Epoch 468/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 10102.7646
# Epoch 469/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 10122.5830
# Epoch 470/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 10106.4814
# Epoch 471/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 10100.4043
# Epoch 472/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 10116.3242
# Epoch 473/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 10108.3604
# Epoch 474/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 10107.2168
# Epoch 475/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 10105.8174
# Epoch 476/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 10102.7666
# Epoch 477/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 10106.9785
# Epoch 478/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 10109.1641
# Epoch 479/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 10099.5312
# Epoch 480/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 10111.4824
# Epoch 481/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 10094.4004
# Epoch 482/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 10105.4062
# Epoch 483/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 10102.7432
# Epoch 484/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 10112.2822
# Epoch 485/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 10107.3457
# Epoch 486/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 10117.2148
# Epoch 487/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 10111.3701
# Epoch 488/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 10111.6523
# Epoch 489/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 10111.6865
# Epoch 490/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 10098.0713
# Epoch 491/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 10097.2900
# Epoch 492/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 10086.4795
# Epoch 493/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 10088.4600
# Epoch 494/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 10089.1230
# Epoch 495/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 10086.8604
# Epoch 496/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 10093.3740
# Epoch 497/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 10085.6602
# Epoch 498/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 10091.8174
# Epoch 499/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 10096.8691
# Epoch 500/500
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 10091.5000
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saved loss curve plot at: /content/drive/MyDrive/BRATS20/Pre_BraTS20_flair/loss_curve_Tumor.png
# Training completed in 264.70 seconds
# GPU memory used: 4481 MB
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saved model architecture diagrams in /content/drive/MyDrive/BRATS20/Pre_BraTS20_flair/saved_models_VAE_Brain_Tumor
# Saved models for Tumor in /content/drive/MyDrive/BRATS20/Pre_BraTS20_flair/saved_models_VAE_Brain_Tumor
# Generating 170 images for class Tumor
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#
# Evaluating model for class: Tumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Inference speed: 263.41 ms per image
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Reconstruction quality:
# - MSE: 0.0023
# - PSNR: 26.60 dB
# - SSIM: 0.8000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7e9b3c368680> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# - FID: 72.68
#
# === Performance Summary for TUMOR ===
# Training time: 264.70 ± 0.00 sec
# Inference time: 263.41 ± 0.00 ms per image
# GPU memory usage: 4481 ± 0 MB
# Reconstruction quality:
# - MSE: 0.0023
# - PSNR: 26.60 dB
# - SSIM: 0.8000
# - FID: 72.68
#
# === Training VAE for class: NOTUMOR ===
# Training samples: 277
# Epoch 1/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 9s 786ms/step - loss: 34025.7031
# Epoch 2/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 33464.3867
# Epoch 3/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 28782.4590
# Epoch 4/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 20034.8516
# Epoch 5/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 15634.2695
# Epoch 6/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 14735.5430
# Epoch 7/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 14312.5215
# Epoch 8/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 14023.0762
# Epoch 9/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 13775.0693
# Epoch 10/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 13585.6348
# Epoch 11/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 13361.8857
# Epoch 12/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 13306.6699
# Epoch 13/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12993.0840
# Epoch 14/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 12854.5273
# Epoch 15/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 12795.3555
# Epoch 16/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 12720.8779
# Epoch 17/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 12682.9736
# Epoch 18/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 12619.8828
# Epoch 19/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 12583.4092
# Epoch 20/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 12551.2158
# Epoch 21/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 12486.1543
# Epoch 22/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 12474.5137
# Epoch 23/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 12422.5566
# Epoch 24/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 12396.1514
# Epoch 25/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 12361.5684
# Epoch 26/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 12374.0889
# Epoch 27/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 12332.2539
# Epoch 28/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 12289.9473
# Epoch 29/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 12261.9932
# Epoch 30/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 12227.3145
# Epoch 31/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 12203.8633
# Epoch 32/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 12175.2109
# Epoch 33/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 12147.9482
# Epoch 34/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12124.4346
# Epoch 35/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 12103.3828
# Epoch 36/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 12054.3154
# Epoch 37/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12038.7559
# Epoch 38/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 12021.4893
# Epoch 39/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 11991.0283
# Epoch 40/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 11995.2588
# Epoch 41/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 11981.0068
# Epoch 42/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 11948.3994
# Epoch 43/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 11940.4385
# Epoch 44/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 11931.6475
# Epoch 45/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 11901.0000
# Epoch 46/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 11874.0400
# Epoch 47/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 
content/drive/MyDrive/BRATS20/Pre_BraTS20_flair/saved_models_VAE_Brain_NoTumor
# Saved models for NoTumor in /content/drive/MyDrive/BRATS20/Pre_BraTS20_flair/saved_models_VAE_Brain_NoTumor
# Generating 723 images for class NoTumor
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
#
# Evaluating model for class: NoTumor
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Inference speed: 113.27 ms per image
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Reconstruction quality:
# - MSE: 0.0031
# - PSNR: 25.26 dB
# - SSIM: 0.7411
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# - FID: 68.67
#
# === Performance Summary for NOTUMOR ===
# Training time: 119.34 ± 0.00 sec
# Inference time: 113.27 ± 0.00 ms per image
# GPU memory usage: 4483 ± 0 MB
# Reconstruction quality:
# - MSE: 0.0031
# - PSNR: 25.26 dB
# - SSIM: 0.7411
# - FID: 68.67
#
# Saved full system architecture diagram at: /content/drive/MyDrive/BRATS20/Pre_BraTS20_flair/full_system_architecture.png
# === Model Architectures ===
# Model: "encoder"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_15      │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_196 (Conv2D) │ (None, 64, 64,    │        896 │ input_layer_15[0… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_197 (Conv2D) │ (None, 32, 32,    │     18,496 │ conv2d_196[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_4 (Flatten) │ (None, 65536)     │          0 │ conv2d_197[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 256)       │ 16,777,472 │ flatten_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_mean (Dense)      │ (None, 100)       │     25,700 │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z_log_var (Dense)   │ (None, 100)       │     25,700 │ dense_8[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ z (Lambda)          │ (None, 100)       │          0 │ z_mean[0][0],     │
# │                     │                   │            │ z_log_var[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 16,848,264 (64.27 MB)
#  Trainable params: 16,848,264 (64.27 MB)
#  Non-trainable params: 0 (0.00 B)
# Model: "decoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_16 (InputLayer)     │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 16384)          │     1,654,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape_4 (Reshape)             │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_12             │ (None, 32, 32, 64)     │        36,928 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_13             │ (None, 64, 64, 32)     │        18,464 │
# │ (Conv2DTranspose)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_transpose_14             │ (None, 128, 128, 3)    │           867 │
# │ (Conv2DTranspose)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,711,043 (6.53 MB)
#  Trainable params: 1,711,043 (6.53 MB)
#  Non-trainable params: 0 (0.00 B)
# Model: "vae"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_17      │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder             │ [(None, 100),     │ 16,848,264 │ input_layer_17[0… │
# │ (Functional)        │ (None, 100),      │            │                   │
# │                     │ (None, 100)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder             │ (None, 128, 128,  │  1,711,043 │ encoder[0][2]     │
# │ (Functional)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ vae_loss_layer_4    │ (None, 128, 128,  │          0 │ input_layer_17[0… │
# │ (VAELossLayer)      │ 3)                │            │ decoder[0][0],    │
# │                     │                   │            │ encoder[0][0],    │
# │                     │                   │            │ encoder[0][1]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 55,677,923 (212.39 MB)
#  Trainable params: 18,559,307 (70.80 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 37,118,616 (141.60 MB)

# %% [markdown]
# Multi class CNN classification without data augmentation (Ultrasound breast cancer dataset)

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, f1_score
import seaborn as sns

# Dataset paths
train_data_dir = "/content/Breast"

# Parameters
img_height = 224
img_width = 224
batch_size = 32
epochs = 20 # You can increase this as needed
num_classes = 3

# 1. Load dataset (No data augmentation)
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_data_dir,
    labels='inferred',
    label_mode='categorical',
    shuffle=True,
    batch_size=batch_size,
    image_size=(img_height, img_width),
    validation_split=0.2,
    subset="training",
    seed=42
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_data_dir,
    labels='inferred',
    label_mode='categorical',
    shuffle=True,
    batch_size=batch_size,
    image_size=(img_height, img_width),
    validation_split=0.2,
    subset="validation",
    seed=42
)

class_names = train_ds.class_names
print("Classes:", class_names)

# Optional: Prefetching for performance
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)

# 2. Build a simple CNN model
model = tf.keras.Sequential([
    tf.keras.layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),

    tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),

    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),

    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(num_classes, activation='softmax')
])

model.summary()

# 3. Compile the model
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# 4. Train the model
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs
)

# 5. Evaluate the model on validation set and display accuracy & loss
val_loss, val_accuracy = model.evaluate(val_ds)
print(f"\nValidation Accuracy: {val_accuracy:.4f}")
print(f"Validation Loss: {val_loss:.4f}\n")

# 6. Plot accuracy and loss curves
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss_hist = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy', marker='o')
plt.plot(epochs_range, val_acc, label='Validation Accuracy', marker='o')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss', marker='o')
plt.plot(epochs_range, val_loss_hist, label='Validation Loss', marker='o')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid()

plt.show()

# 7. Get predictions and true labels from validation set
val_labels = []
val_preds = []

for images, labels in val_ds:
    preds = model.predict(images)
    val_preds.extend(np.argmax(preds, axis=1))
    val_labels.extend(np.argmax(labels.numpy(), axis=1))

# 8. Confusion Matrix
cm = confusion_matrix(val_labels, val_preds)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# 9. F1 Score & Classification Report
f1 = f1_score(val_labels, val_preds, average='weighted')
print(f"Weighted F1 Score: {f1:.4f}\n")

print("Classification Report:\n")
print(classification_report(val_labels, val_preds, target_names=class_names))
# Out:
# Found 780 files belonging to 3 classes.
# Using 624 files for training.
# Found 780 files belonging to 3 classes.
# Using 156 files for validation.
# Classes: ['benign', 'malignant', 'normal']
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling_1 (Rescaling)         │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 52, 52, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 26, 26, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 86528)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │    11,075,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 3)              │           387 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,169,347 (42.61 MB)
#  Trainable params: 11,169,347 (42.61 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 22s 622ms/step - accuracy: 0.4775 - loss: 1.5689 - val_accuracy: 0.5449 - val_loss: 1.0695
# Epoch 2/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 381ms/step - accuracy: 0.5533 - loss: 0.9982 - val_accuracy: 0.6090 - val_loss: 0.8894
# Epoch 3/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 185ms/step - accuracy: 0.6523 - loss: 0.8083 - val_accuracy: 0.6218 - val_loss: 0.8647
# Epoch 4/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 212ms/step - accuracy: 0.6953 - loss: 0.6861 - val_accuracy: 0.6218 - val_loss: 0.9684
# Epoch 5/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 226ms/step - accuracy: 0.7337 - loss: 0.6806 - val_accuracy: 0.6731 - val_loss: 0.9292
# Epoch 6/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 321ms/step - accuracy: 0.7959 - loss: 0.5290 - val_accuracy: 0.6410 - val_loss: 1.1847
# Epoch 7/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 412ms/step - accuracy: 0.8211 - loss: 0.4326 - val_accuracy: 0.6731 - val_loss: 1.0434
# Epoch 8/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 270ms/step - accuracy: 0.8369 - loss: 0.3731 - val_accuracy: 0.6987 - val_loss: 1.2559
# Epoch 9/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 9s 183ms/step - accuracy: 0.9151 - loss: 0.2554 - val_accuracy: 0.6859 - val_loss: 1.3639
# Epoch 10/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 253ms/step - accuracy: 0.9478 - loss: 0.1842 - val_accuracy: 0.6731 - val_loss: 1.7049
# Epoch 11/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 279ms/step - accuracy: 0.9446 - loss: 0.1687 - val_accuracy: 0.6731 - val_loss: 1.5209
# Epoch 12/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 213ms/step - accuracy: 0.9405 - loss: 0.1861 - val_accuracy: 0.6731 - val_loss: 1.9915
# Epoch 13/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 362ms/step - accuracy: 0.9594 - loss: 0.1213 - val_accuracy: 0.6859 - val_loss: 1.8524
# Epoch 14/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 212ms/step - accuracy: 0.9610 - loss: 0.1015 - val_accuracy: 0.6859 - val_loss: 2.2221
# Epoch 15/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 283ms/step - accuracy: 0.9641 - loss: 0.0822 - val_accuracy: 0.6731 - val_loss: 2.2961
# Epoch 16/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 248ms/step - accuracy: 0.9782 - loss: 0.0786 - val_accuracy: 0.6923 - val_loss: 1.9117
# Epoch 17/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 238ms/step - accuracy: 0.9803 - loss: 0.0650 - val_accuracy: 0.6987 - val_loss: 2.1168
# Epoch 18/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 257ms/step - accuracy: 0.9692 - loss: 0.0973 - val_accuracy: 0.6795 - val_loss: 1.7752
# Epoch 19/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 12s 378ms/step - accuracy: 0.9749 - loss: 0.0885 - val_accuracy: 0.6795 - val_loss: 2.1462
# Epoch 20/20
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 211ms/step - accuracy: 0.9819 - loss: 0.0856 - val_accuracy: 0.6731 - val_loss: 2.9162
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - accuracy: 0.6705 - loss: 2.5549
#
# Validation Accuracy: 0.6731
# Validation Loss: 2.9162
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 852ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step
# Weighted F1 Score: 0.6593
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#       benign       0.69      0.85      0.76        85
#    malignant       0.69      0.45      0.55        44
#       normal       0.59      0.48      0.53        27
#
#     accuracy                           0.67       156
#    macro avg       0.66      0.59      0.61       156
# weighted avg       0.67      0.67      0.66       156

# %% [markdown]
# Binary CNN classification without data augmentation (BraTs 2020)

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, f1_score
import seaborn as sns

# Dataset paths
data_dir = "/content/BRATS20/Pre_BraTS20_flair"

# Parameters
img_height = 224
img_width = 224
batch_size = 32
epochs = 20

# Load dataset (binary labels)
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    labels='inferred',
    label_mode='binary',
    shuffle=True,
    batch_size=batch_size,
    image_size=(img_height, img_width),
    validation_split=0.2,
    subset="training",
    seed=42
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    labels='inferred',
    label_mode='binary',
    shuffle=True,
    batch_size=batch_size,
    image_size=(img_height, img_width),
    validation_split=0.2,
    subset="validation",
    seed=42
)

class_names = train_ds.class_names
print("Classes:", class_names)

# Optional: Performance boost
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)

# Build CNN model
model = tf.keras.Sequential([
    tf.keras.layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),

    tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),

    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),

    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(1, activation='sigmoid')  # Binary classification
])

model.summary()

# Compile model
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# Train model
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs
)

# Evaluate on validation set
val_loss, val_accuracy = model.evaluate(val_ds)
print(f"\nValidation Accuracy: {val_accuracy:.4f}")
print(f"Validation Loss: {val_loss:.4f}\n")

# Plot accuracy and loss
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss_hist = history.history['val_loss']
epochs_range = range(epochs)

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy', marker='o')
plt.plot(epochs_range, val_acc, label='Validation Accuracy', marker='o')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss', marker='o')
plt.plot(epochs_range, val_loss_hist, label='Validation Loss', marker='o')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid()

plt.show()

# Predict and evaluate
val_labels = []
val_preds = []

for images, labels in val_ds:
    preds = model.predict(images)
    val_preds.extend((preds > 0.5).astype(int).flatten())  # Threshold sigmoid
    val_labels.extend(labels.numpy().flatten())

# Confusion Matrix
cm = confusion_matrix(val_labels, val_preds)

plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# F1 Score & Classification Report
f1 = f1_score(val_labels, val_preds)
print(f"F1 Score: {f1:.4f}\n")

print("Classification Report:\n")
print(classification_report(val_labels, val_preds, target_names=class_names))
# Out:
# Found 1107 files belonging to 2 classes.
# Using 886 files for training.
# Found 1107 files belonging to 2 classes.
# Using 221 files for validation.
# Classes: ['NoTumor', 'Tumor']
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/preprocessing/tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling_2 (Rescaling)         │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 52, 52, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 26, 26, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 86528)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │    11,075,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,169,089 (42.61 MB)
#  Trainable params: 11,169,089 (42.61 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 10s 264ms/step - accuracy: 0.6996 - loss: 0.7872 - val_accuracy: 0.7738 - val_loss: 0.5210
# Epoch 2/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.7516 - loss: 0.5239 - val_accuracy: 0.7783 - val_loss: 0.4968
# Epoch 3/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.7543 - loss: 0.5092 - val_accuracy: 0.7783 - val_loss: 0.4983
# Epoch 4/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.7961 - loss: 0.4713 - val_accuracy: 0.7738 - val_loss: 0.4859
# Epoch 5/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.7927 - loss: 0.4557 - val_accuracy: 0.7692 - val_loss: 0.4792
# Epoch 6/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.7937 - loss: 0.4258 - val_accuracy: 0.7466 - val_loss: 0.5304
# Epoch 7/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.8169 - loss: 0.3789 - val_accuracy: 0.7828 - val_loss: 0.4694
# Epoch 8/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.8498 - loss: 0.3522 - val_accuracy: 0.8054 - val_loss: 0.4607
# Epoch 9/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.8680 - loss: 0.2899 - val_accuracy: 0.8009 - val_loss: 0.4739
# Epoch 10/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.8936 - loss: 0.2610 - val_accuracy: 0.7964 - val_loss: 0.4821
# Epoch 11/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.8934 - loss: 0.2280 - val_accuracy: 0.7376 - val_loss: 0.5667
# Epoch 12/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.9216 - loss: 0.1814 - val_accuracy: 0.8190 - val_loss: 0.5466
# Epoch 13/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.9536 - loss: 0.1221 - val_accuracy: 0.7828 - val_loss: 0.6176
# Epoch 14/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.9464 - loss: 0.1384 - val_accuracy: 0.7964 - val_loss: 0.6208
# Epoch 15/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.9685 - loss: 0.0894 - val_accuracy: 0.7692 - val_loss: 0.7823
# Epoch 16/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - accuracy: 0.9587 - loss: 0.1075 - val_accuracy: 0.7964 - val_loss: 0.7416
# Epoch 17/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9796 - loss: 0.0750 - val_accuracy: 0.8009 - val_loss: 0.7276
# Epoch 18/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.9800 - loss: 0.0644 - val_accuracy: 0.7692 - val_loss: 0.7893
# Epoch 19/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.9846 - loss: 0.0418 - val_accuracy: 0.7873 - val_loss: 0.7444
# Epoch 20/20
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.9841 - loss: 0.0497 - val_accuracy: 0.7964 - val_loss: 0.8145
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8055 - loss: 0.8463
#
# Validation Accuracy: 0.7964
# Validation Loss: 0.8145
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 603ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step
# F1 Score: 0.8732
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#      NoTumor       0.55      0.43      0.48        49
#        Tumor       0.85      0.90      0.87       172
#
#     accuracy                           0.80       221
#    macro avg       0.70      0.66      0.68       221
# weighted avg       0.78      0.80      0.79       221

# %% [markdown]
# Multi class CNN classification with VAE (Ultrasound breast cancer dataset)

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, f1_score
import seaborn as sns

# Dataset paths
train_data_dir = "/content/Breast"

# Parameters
img_height = 224
img_width = 224
batch_size = 32
epochs = 20 # You can increase this as needed
num_classes = 3

# 1. Load dataset (No data augmentation)
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_data_dir,
    labels='inferred',
    label_mode='categorical',
    shuffle=True,
    batch_size=batch_size,
    image_size=(img_height, img_width),
    validation_split=0.2,
    subset="training",
    seed=42
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_data_dir,
    labels='inferred',
    label_mode='categorical',
    shuffle=True,
    batch_size=batch_size,
    image_size=(img_height, img_width),
    validation_split=0.2,
    subset="validation",
    seed=42
)

class_names = train_ds.class_names
print("Classes:", class_names)

# Optional: Prefetching for performance
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)

# 2. Build a simple CNN model
model = tf.keras.Sequential([
    tf.keras.layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),

    tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),

    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),

    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(num_classes, activation='softmax')
])

model.summary()

# 3. Compile the model
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# 4. Train the model
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs
)

# 5. Evaluate the model on validation set and display accuracy & loss
val_loss, val_accuracy = model.evaluate(val_ds)
print(f"\nValidation Accuracy: {val_accuracy:.4f}")
print(f"Validation Loss: {val_loss:.4f}\n")

# 6. Plot accuracy and loss curves
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss_hist = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy', marker='o')
plt.plot(epochs_range, val_acc, label='Validation Accuracy', marker='o')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss', marker='o')
plt.plot(epochs_range, val_loss_hist, label='Validation Loss', marker='o')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid()

plt.show()

# 7. Get predictions and true labels from validation set
val_labels = []
val_preds = []

for images, labels in val_ds:
    preds = model.predict(images)
    val_preds.extend(np.argmax(preds, axis=1))
    val_labels.extend(np.argmax(labels.numpy(), axis=1))

# 8. Confusion Matrix
cm = confusion_matrix(val_labels, val_preds)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# 9. F1 Score & Classification Report
f1 = f1_score(val_labels, val_preds, average='weighted')
print(f"Weighted F1 Score: {f1:.4f}\n")

print("Classification Report:\n")
print(classification_report(val_labels, val_preds, target_names=class_names))
# Out:
# Found 1311 files belonging to 3 classes.
# Using 1049 files for training.
# Found 1311 files belonging to 3 classes.
# Using 262 files for validation.
# Classes: ['benign', 'malignant', 'normal']
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/preprocessing/tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling_3 (Rescaling)         │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 52, 52, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 26, 26, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 86528)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 128)            │    11,075,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 3)              │           387 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,169,347 (42.61 MB)
#  Trainable params: 11,169,347 (42.61 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 14s 346ms/step - accuracy: 0.3967 - loss: 1.4104 - val_accuracy: 0.4771 - val_loss: 1.1427
# Epoch 2/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 12s 144ms/step - accuracy: 0.5935 - loss: 0.8678 - val_accuracy: 0.6870 - val_loss: 0.7513
# Epoch 3/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 145ms/step - accuracy: 0.7121 - loss: 0.6765 - val_accuracy: 0.7672 - val_loss: 0.5402
# Epoch 4/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 179ms/step - accuracy: 0.7984 - loss: 0.4710 - val_accuracy: 0.8130 - val_loss: 0.4857
# Epoch 5/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 164ms/step - accuracy: 0.8912 - loss: 0.3051 - val_accuracy: 0.8473 - val_loss: 0.4551
# Epoch 6/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 11s 193ms/step - accuracy: 0.9287 - loss: 0.2085 - val_accuracy: 0.8473 - val_loss: 0.5318
# Epoch 7/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 155ms/step - accuracy: 0.9438 - loss: 0.1664 - val_accuracy: 0.8397 - val_loss: 0.6609
# Epoch 8/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 11s 190ms/step - accuracy: 0.9589 - loss: 0.1220 - val_accuracy: 0.8435 - val_loss: 0.5973
# Epoch 9/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - accuracy: 0.9674 - loss: 0.1112 - val_accuracy: 0.8893 - val_loss: 0.5322
# Epoch 10/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 8s 252ms/step - accuracy: 0.9684 - loss: 0.1318 - val_accuracy: 0.8664 - val_loss: 0.5562
# Epoch 11/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 4s 129ms/step - accuracy: 0.9769 - loss: 0.0714 - val_accuracy: 0.8664 - val_loss: 0.5844
# Epoch 12/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 184ms/step - accuracy: 0.9898 - loss: 0.0485 - val_accuracy: 0.8664 - val_loss: 0.5915
# Epoch 13/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 144ms/step - accuracy: 0.9808 - loss: 0.0621 - val_accuracy: 0.8435 - val_loss: 0.6218
# Epoch 14/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 208ms/step - accuracy: 0.9739 - loss: 0.0798 - val_accuracy: 0.8588 - val_loss: 0.4620
# Epoch 15/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 4s 131ms/step - accuracy: 0.9389 - loss: 0.1737 - val_accuracy: 0.8168 - val_loss: 0.8277
# Epoch 16/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 144ms/step - accuracy: 0.9824 - loss: 0.0683 - val_accuracy: 0.8473 - val_loss: 0.6282
# Epoch 17/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 170ms/step - accuracy: 0.9870 - loss: 0.0486 - val_accuracy: 0.8550 - val_loss: 0.6055
# Epoch 18/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 4s 130ms/step - accuracy: 0.9804 - loss: 0.0459 - val_accuracy: 0.8664 - val_loss: 0.6988
# Epoch 19/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 171ms/step - accuracy: 0.9883 - loss: 0.0427 - val_accuracy: 0.8626 - val_loss: 0.7457
# Epoch 20/20
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - accuracy: 0.9951 - loss: 0.0263 - val_accuracy: 0.8435 - val_loss: 0.7018
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.8461 - loss: 0.6879
#
# Validation Accuracy: 0.8435
# Validation Loss: 0.7018
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7e1b8e0b6480> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 622ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# Weighted F1 Score: 0.8450
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#       benign       0.74      0.81      0.78        79
#    malignant       0.94      0.83      0.88        89
#       normal       0.86      0.88      0.87        94
#
#     accuracy                           0.84       262
#    macro avg       0.85      0.84      0.84       262
# weighted avg       0.85      0.84      0.84       262

# %% [markdown]
# Binary CNN classification with VAE (BraTs 2020)

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, f1_score
import seaborn as sns

# Dataset paths
data_dir = "/content/BRATS20/Pre_BraTS20_flair"

# Parameters
img_height = 224
img_width = 224
batch_size = 32
epochs = 20

# Load dataset (binary labels)
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    labels='inferred',
    label_mode='binary',
    shuffle=True,
    batch_size=batch_size,
    image_size=(img_height, img_width),
    validation_split=0.2,
    subset="training",
    seed=42
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    labels='inferred',
    label_mode='binary',
    shuffle=True,
    batch_size=batch_size,
    image_size=(img_height, img_width),
    validation_split=0.2,
    subset="validation",
    seed=42
)

class_names = train_ds.class_names
print("Classes:", class_names)

# Optional: Performance boost
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)

# Build CNN model
model = tf.keras.Sequential([
    tf.keras.layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),

    tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),

    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),

    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(1, activation='sigmoid')  # Binary classification
])

model.summary()

# Compile model
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# Train model
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs
)

# Evaluate on validation set
val_loss, val_accuracy = model.evaluate(val_ds)
print(f"\nValidation Accuracy: {val_accuracy:.4f}")
print(f"Validation Loss: {val_loss:.4f}\n")

# Plot accuracy and loss
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss_hist = history.history['val_loss']
epochs_range = range(epochs)

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy', marker='o')
plt.plot(epochs_range, val_acc, label='Validation Accuracy', marker='o')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid()

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss', marker='o')
plt.plot(epochs_range, val_loss_hist, label='Validation Loss', marker='o')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid()

plt.show()

# Predict and evaluate
val_labels = []
val_preds = []

for images, labels in val_ds:
    preds = model.predict(images)
    val_preds.extend((preds > 0.5).astype(int).flatten())  # Threshold sigmoid
    val_labels.extend(labels.numpy().flatten())

# Confusion Matrix
cm = confusion_matrix(val_labels, val_preds)

plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# F1 Score & Classification Report
f1 = f1_score(val_labels, val_preds)
print(f"F1 Score: {f1:.4f}\n")

print("Classification Report:\n")
print(classification_report(val_labels, val_preds, target_names=class_names))
# Out:
# Found 1660 files belonging to 2 classes.
# Using 1328 files for training.
# Found 1660 files belonging to 2 classes.
# Using 332 files for validation.
# Classes: ['NoTumor', 'Tumor']
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/preprocessing/tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling_4 (Rescaling)         │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_12 (Conv2D)              │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_12 (MaxPooling2D) │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_13 (MaxPooling2D) │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 52, 52, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_14 (MaxPooling2D) │ (None, 26, 26, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 86528)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 128)            │    11,075,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 11,169,089 (42.61 MB)
#  Trainable params: 11,169,089 (42.61 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 9s 142ms/step - accuracy: 0.7048 - loss: 0.6542 - val_accuracy: 0.7831 - val_loss: 0.4181
# Epoch 2/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.8200 - loss: 0.4002 - val_accuracy: 0.7892 - val_loss: 0.3961
# Epoch 3/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.8350 - loss: 0.3634 - val_accuracy: 0.8343 - val_loss: 0.3732
# Epoch 4/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.8579 - loss: 0.3484 - val_accuracy: 0.8283 - val_loss: 0.3644
# Epoch 5/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.8656 - loss: 0.3337 - val_accuracy: 0.8012 - val_loss: 0.3796
# Epoch 6/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.8864 - loss: 0.2769 - val_accuracy: 0.8102 - val_loss: 0.4216
# Epoch 7/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.8959 - loss: 0.2321 - val_accuracy: 0.8343 - val_loss: 0.3791
# Epoch 8/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9022 - loss: 0.2529 - val_accuracy: 0.8373 - val_loss: 0.4569
# Epoch 9/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.9369 - loss: 0.1649 - val_accuracy: 0.8434 - val_loss: 0.4389
# Epoch 10/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9425 - loss: 0.1272 - val_accuracy: 0.8464 - val_loss: 0.4520
# Epoch 11/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.9638 - loss: 0.0976 - val_accuracy: 0.8253 - val_loss: 0.4862
# Epoch 12/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9746 - loss: 0.0797 - val_accuracy: 0.8434 - val_loss: 0.5606
# Epoch 13/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.9776 - loss: 0.0588 - val_accuracy: 0.8012 - val_loss: 0.6887
# Epoch 14/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.9731 - loss: 0.0715 - val_accuracy: 0.8464 - val_loss: 0.6395
# Epoch 15/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.9854 - loss: 0.0404 - val_accuracy: 0.8253 - val_loss: 0.7438
# Epoch 16/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9914 - loss: 0.0215 - val_accuracy: 0.8253 - val_loss: 0.7427
# Epoch 17/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9952 - loss: 0.0226 - val_accuracy: 0.8253 - val_loss: 0.8324
# Epoch 18/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.9923 - loss: 0.0143 - val_accuracy: 0.8373 - val_loss: 0.8371
# Epoch 19/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9987 - loss: 0.0077 - val_accuracy: 0.8193 - val_loss: 0.9041
# Epoch 20/20
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.9966 - loss: 0.0091 - val_accuracy: 0.8404 - val_loss: 1.0233
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8265 - loss: 1.1930
#
# Validation Accuracy: 0.8404
# Validation Loss: 1.0233
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step
# F1 Score: 0.8548
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#      NoTumor       0.84      0.80      0.82       153
#        Tumor       0.84      0.87      0.85       179
#
#     accuracy                           0.84       332
#    macro avg       0.84      0.84      0.84       332
# weighted avg       0.84      0.84      0.84       332

# %%
import os

folder_path = '/content/BRATS20/Pre_BraTS20_flair/Tumor'  # Change this to your folder path

# Count all PNG images
image_count = len([f for f in os.listdir(folder_path) if f.lower().endswith(('.png', '.jpg', '.jpeg'))])

print(f"Number of images: {image_count}")
# Out:
# Number of images: 830

# %%
import os
import shutil

source_dir = '/content/drive/MyDrive/Breast/malignant'
destination_dir = '/content/Breast/malignant'

# Create destination if it doesn't exist
os.makedirs(destination_dir, exist_ok=True)

# Copy all files from source to destination
for filename in os.listdir(source_dir):
    src_path = os.path.join(source_dir, filename)
    dst_path = os.path.join(destination_dir, filename)

    if os.path.isfile(src_path):  # Only copy files
        shutil.copy2(src_path, dst_path)

print("Images copied successfully.")
# Out:
# Images copied successfully.

# %%
import os
import shutil

source_dir = '/content/drive/MyDrive/BRATS20/Pre_BraTS20_flair/generated_VAE_Breast_NoTumor'
destination_dir = '/content/BRATS20/Pre_BraTS20_flair/NoTumor'
num_images_to_copy = 553  # Set how many images you want to copy

# Create destination if it doesn't exist
os.makedirs(destination_dir, exist_ok=True)

# List image files (filtering only files)
image_files = [f for f in os.listdir(source_dir) if os.path.isfile(os.path.join(source_dir, f))]

# Copy the specified number
for i, filename in enumerate(image_files[:num_images_to_copy]):
    src_path = os.path.join(source_dir, filename)
    dst_path = os.path.join(destination_dir, filename)
    shutil.copy2(src_path, dst_path)

print(f"{num_images_to_copy} images copied successfully.")
# Out:
# 553 images copied successfully.
